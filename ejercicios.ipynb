# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

from importlib import reload
import lib.base
reload(lib.base)
from lib.base import graficar, met_biseccion, met_regula_falsi, met_newton_raphson
from lib.base import met_secante

# %% [markdown]
# #### 1

# %%
f = lambda x: ((np.cos(np.e**x)) + x)
graficar(f, -2, 0, 1000, 6)
met_biseccion(f, -2, 0, 1e-5)
# Out:
# ite 1 : a_0  = -2.0000, b_0  = 0.0000, p_1  = -1.00000 | e_abs: 1.000000e+00
# ite 2 : a_1  = -1.0000, b_1  = 0.0000, p_2  = -0.50000 | e_abs: 5.000000e-01
# ite 3 : a_2  = -1.0000, b_2  = -0.5000, p_3  = -0.75000 | e_abs: 2.500000e-01
# ite 4 : a_3  = -1.0000, b_3  = -0.7500, p_4  = -0.87500 | e_abs: 1.250000e-01
# ite 5 : a_4  = -1.0000, b_4  = -0.8750, p_5  = -0.93750 | e_abs: 6.250000e-02
# ite 6 : a_5  = -0.9375, b_5  = -0.8750, p_6  = -0.90625 | e_abs: 3.125000e-02
# ite 7 : a_6  = -0.9375, b_6  = -0.9062, p_7  = -0.92188 | e_abs: 1.562500e-02
# ite 8 : a_7  = -0.9375, b_7  = -0.9219, p_8  = -0.92969 | e_abs: 7.812500e-03
# ite 9 : a_8  = -0.9297, b_8  = -0.9219, p_9  = -0.92578 | e_abs: 3.906250e-03
# ite 10: a_9  = -0.9258, b_9  = -0.9219, p_10 = -0.92383 | e_abs: 1.953125e-03
# ite 11: a_10 = -0.9238, b_10 = -0.9219, p_11 = -0.92285 | e_abs: 9.765625e-04
# ite 12: a_11 = -0.9229, b_11 = -0.9219, p_12 = -0.92236 | e_abs: 4.882812e-04
# ...
